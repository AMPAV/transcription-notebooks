# %% [markdown]
# # Conclusions
#
# Using AMPAV you can experiment with different metadata tools within a
# Jupyter Notebook but that's not all -- the packages can be used in any
# python script including batch processing, REST APIs, or whatever.
