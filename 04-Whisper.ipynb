# %% [markdown]
# # OpenAI Whisper
#
# OpenAI's Whisper is a free text to speech tool that can be run on your local
# computer.  AMPAV provides a package to use the tool
#
# As before, let's import the tool function into the code.  We'll also import the
# `Path` class

# %%
from ampav.whisper.transcribe import transcribe_file
from pathlib import Path

# %% [markdown]
# The `transcribe_file` function takes several arguments:
# * A `Path` object which is the file to transcribe
# * The name of the model to use (tiny, base, small, medium, turbo, large)
# * The language code to detect or `None` to use automatic detection
# * A device name, either `cpu` or `cuda`.  If you have an nvidia GPU you
#   can try to change the device to `cuda` -- but be advised that most laptop
#   GPUs don't have enough memory to run whisper
#
# When changing the model or device you may need to restart the kernel and re-run
# all of the code blocks.

# %%
file = Path("gettysburg.wav")
modelname = "small"
language = None
device = "cpu"
ts = transcribe_file(file, modelname, language, device)
# Out:
# /home/bdwheele/work_projects/AMPAV-JupyterLab/transcription-notebooks/.venv/lib64/python3.12/site-packages/whisper/transcribe.py:130: UserWarning: Performing inference on CPU when CUDA is available
#   warnings.warn("Performing inference on CPU when CUDA is available")
# /home/bdwheele/work_projects/AMPAV-JupyterLab/transcription-notebooks/.venv/lib64/python3.12/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %% [markdown]
# As in the Transcripts notebook, `transcribe_file` has returned a `Transcript`
# object and we can view the same information about the tool and the transcript
# itself

# %%
print(f"Tool name: {ts.tool_name}")
print(f"Tool version: {ts.tool_version}")
print(f"Tool run time: {ts.run_duration()}")
print(f"First 30 characters of the transcript: {ts.output.text[0:30]}")
print(f"Number of words in the transcript: {len(ts.output.words)}")
print(f"Number of paragraphs in the transcript: {(len(ts.output.paragraphs))}")
# Out:
# Tool name: whisper
# Tool version: None
# Tool run time: 8.542857646942139
# First 30 characters of the transcript: 140 years ago today, President
# Number of words in the transcript: 75
# Number of paragraphs in the transcript: 6

# %% [markdown]
# This time, we can see that the tool's runtime is populated because this tool
# provides this information.  It also provides more information about the
# parameters used by the tool

# %%
print(f"Tool parameters: {ts.parameters}")
# Out:
# Tool parameters: {'model': 'small', 'language': 'en', 'device': 'cpu', 'content_source': 'gettysburg.wav'}

# %% [markdown]
# We can view all of the transcript details by printing the YAML version of the
# object

# %%
print(ts.model_dump_yaml())
# Out:
# ampav_format: tooloutput/1
# end_time: 1776870239.6695962
# messages: []
# output:
#   ampav_format: transcript/1
#   media_duration: 183.04
#   paragraphs:
#   - end_time: 6.1
#     start_time: 0.0
#     text: 140 years ago today, President Abraham Lincoln stood at the site of one
#       of the most important
#   - end_time: 11.96
#     start_time: 6.1
#     text: battles of the U.S. Civil War in Gettysburg, Pennsylvania. A crowd of some
#       15,000 had gathered
#   - end_time: 17.74
#     start_time: 11.96
#     text: to consecrate a cemetery for Union war dead. Though brief, the now famous
#       Gettysburg Address
#   - end_time: 23.2
#     start_time: 17.74
#     text: marked a defining moment of the Civil War. Actor Sam Waterston has portrayed
#       President
#   - end_time: 24.98
#     start_time: 23.2
#     text: Lincoln on stage and screen.
#   - end_time: 28.12
#     start_time: 24.98
#     text: Four score and seven years ago.
#   text: 140 years ago today, President Abraham Lincoln stood at the site of one of
#     the most important battles of the U.S. Civil War in Gettysburg, Pennsylvania.
#     A crowd of some 15,000 had gathered to consecrate a cemetery for Union war dead.
#     Though brief, the now famous Gettysburg Address marked a defining moment of the
#     Civil War. Actor Sam Waterston has portrayed President Lincoln on stage and screen.
#     Four score and seven years ago.
#   words:
#   - end_time: 1.08
#     prefix: ' '
#     start_time: 0.0
#     word: '140'
#   - end_time: 1.8
#     prefix: ' '
#     start_time: 1.08
#     word: years
#   - end_time: 2.08
#     prefix: ' '
#     start_time: 1.8
#     word: ago
#   - end_time: 2.44
#     prefix: ' '
#     start_time: 2.08
#     suffix: ','
#     word: today
#   - end_time: 3.1
#     prefix: ' '
#     start_time: 2.8
#     word: President
#   - end_time: 3.58
#     prefix: ' '
#     start_time: 3.1
#     word: Abraham
#   - end_time: 4.02
#     prefix: ' '
#     start_time: 3.58
#     word: Lincoln
#   - end_time: 4.38
#     prefix: ' '
#     start_time: 4.02
#     word: stood
#   - end_time: 4.6
#     prefix: ' '
#     start_time: 4.38
#     word: at
#   - end_time: 4.72
#     prefix: ' '
#     start_time: 4.6
#     word: the
#   - end_time: 5.04
#     prefix: ' '
#     start_time: 4.72
#     word: site
#   - end_time: 5.2
#     prefix: ' '
#     start_time: 5.04
#     word: of
#   - end_time: 5.32
#     prefix: ' '
#     start_time: 5.2
#     word: one
#   - end_time: 5.4
#     prefix: ' '
#     start_time: 5.32
#     word: of
#   - end_time: 5.5
#     prefix: ' '
#     start_time: 5.4
#     word: the
#   - end_time: 5.66
#     prefix: ' '
#     start_time: 5.5
#     word: most
#   - end_time: 6.1
#     prefix: ' '
#     start_time: 5.66
#     word: important
#   - end_time: 6.52
#     prefix: ' '
#     start_time: 6.1
#     word: battles
#   - end_time: 6.8
#     prefix: ' '
#     start_time: 6.52
#     word: of
#   - end_time: 6.88
#     prefix: ' '
#     start_time: 6.8
#     word: the
#   - end_time: 7.04
#     prefix: ' '
#     start_time: 6.88
#     word: U
#   - end_time: 7.18
#     prefix: .
#     start_time: 7.04
#     suffix: .
#     word: S
#   - end_time: 7.38
#     prefix: ' '
#     start_time: 7.22
#     word: Civil
#   - end_time: 7.72
#     prefix: ' '
#     start_time: 7.38
#     word: War
#   - end_time: 7.96
#     prefix: ' '
#     start_time: 7.72
#     word: in
#   - end_time: 8.46
#     prefix: ' '
#     start_time: 7.96
#     suffix: ','
#     word: Gettysburg
#   - end_time: 9.18
#     prefix: ' '
#     start_time: 8.6
#     suffix: .
#     word: Pennsylvania
#   - end_time: 9.88
#     prefix: ' '
#     start_time: 9.68
#     word: A
#   - end_time: 10.02
#     prefix: ' '
#     start_time: 9.88
#     word: crowd
#   - end_time: 10.18
#     prefix: ' '
#     start_time: 10.02
#     word: of
#   - end_time: 10.42
#     prefix: ' '
#     start_time: 10.18
#     word: some
#   - end_time: 10.94
#     prefix: ' '
#     start_time: 10.42
#     word: '15'
#   - end_time: 11.48
#     prefix: ','
#     start_time: 10.94
#     word: '000'
#   - end_time: 11.68
#     prefix: ' '
#     start_time: 11.48
#     word: had
#   - end_time: 11.96
#     prefix: ' '
#     start_time: 11.68
#     word: gathered
#   - end_time: 12.2
#     prefix: ' '
#     start_time: 11.96
#     word: to
#   - end_time: 12.66
#     prefix: ' '
#     start_time: 12.2
#     word: consecrate
#   - end_time: 12.78
#     prefix: ' '
#     start_time: 12.66
#     word: a
#   - end_time: 13.24
#     prefix: ' '
#     start_time: 12.78
#     word: cemetery
#   - end_time: 13.58
#     prefix: ' '
#     start_time: 13.24
#     word: for
#   - end_time: 13.96
#     prefix: ' '
#     start_time: 13.58
#     word: Union
#   - end_time: 14.26
#     prefix: ' '
#     start_time: 13.96
#     word: war
#   - end_time: 14.54
#     prefix: ' '
#     start_time: 14.26
#     suffix: .
#     word: dead
#   - end_time: 15.34
#     prefix: ' '
#     start_time: 15.04
#     word: Though
#   - end_time: 15.7
#     prefix: ' '
#     start_time: 15.34
#     suffix: ','
#     word: brief
#   - end_time: 16.16
#     prefix: ' '
#     start_time: 16.08
#     word: the
#   - end_time: 16.34
#     prefix: ' '
#     start_time: 16.16
#     word: now
#   - end_time: 16.68
#     prefix: ' '
#     start_time: 16.34
#     word: famous
#   - end_time: 17.42
#     prefix: ' '
#     start_time: 16.68
#     word: Gettysburg
#   - end_time: 17.74
#     prefix: ' '
#     start_time: 17.42
#     word: Address
#   - end_time: 18.26
#     prefix: ' '
#     start_time: 17.74
#     word: marked
#   - end_time: 18.38
#     prefix: ' '
#     start_time: 18.26
#     word: a
#   - end_time: 18.82
#     prefix: ' '
#     start_time: 18.38
#     word: defining
#   - end_time: 19.18
#     prefix: ' '
#     start_time: 18.82
#     word: moment
#   - end_time: 19.4
#     prefix: ' '
#     start_time: 19.18
#     word: of
#   - end_time: 19.5
#     prefix: ' '
#     start_time: 19.4
#     word: the
#   - end_time: 19.7
#     prefix: ' '
#     start_time: 19.5
#     word: Civil
#   - end_time: 20.12
#     prefix: ' '
#     start_time: 19.7
#     suffix: .
#     word: War
#   - end_time: 21.06
#     prefix: ' '
#     start_time: 20.56
#     word: Actor
#   - end_time: 21.38
#     prefix: ' '
#     start_time: 21.06
#     word: Sam
#   - end_time: 21.96
#     prefix: ' '
#     start_time: 21.38
#     word: Waterston
#   - end_time: 22.28
#     prefix: ' '
#     start_time: 21.96
#     word: has
#   - end_time: 22.74
#     prefix: ' '
#     start_time: 22.28
#     word: portrayed
#   - end_time: 23.2
#     prefix: ' '
#     start_time: 22.74
#     word: President
#   - end_time: 23.58
#     prefix: ' '
#     start_time: 23.2
#     word: Lincoln
#   - end_time: 23.94
#     prefix: ' '
#     start_time: 23.58
#     word: 'on'
#   - end_time: 24.34
#     prefix: ' '
#     start_time: 23.94
#     word: stage
#   - end_time: 24.64
#     prefix: ' '
#     start_time: 24.34
#     word: and
#   - end_time: 24.98
#     prefix: ' '
#     start_time: 24.64
#     suffix: .
#     word: screen
#   - end_time: 26.0
#     prefix: ' '
#     start_time: 24.98
#     word: Four
#   - end_time: 26.5
#     prefix: ' '
#     start_time: 26.0
#     word: score
#   - end_time: 26.94
#     prefix: ' '
#     start_time: 26.5
#     word: and
#   - end_time: 27.28
#     prefix: ' '
#     start_time: 26.94
#     word: seven
#   - end_time: 27.7
#     prefix: ' '
#     start_time: 27.28
#     word: years
#   - end_time: 28.12
#     prefix: ' '
#     start_time: 27.7
#     suffix: .
#     word: ago
# parameters:
#   content_source: gettysburg.wav
#   device: cpu
#   language: en
#   model: small
# start_time: 1776870231.1267385
# tool_name: whisper

# %% [markdown]
# Transcripts are great but what if we wanted a WebVTT?  `ampav.core` provides a
# function to convert a list of paragraphs

# %%
from ampav.core.file_formats.webvtt import paragraphs_to_webvtt
print(paragraphs_to_webvtt(ts.output.paragraphs))
# Out:
# WEBVTT
#
# 00:00:00.000 --> 00:00:06.100
# 140 years ago today, President Abraham Lincoln stood at the site of one of the most important
#
# 00:00:06.100 --> 00:00:11.960
# battles of the U.S. Civil War in Gettysburg, Pennsylvania. A crowd of some 15,000 had gathered
#
# 00:00:11.960 --> 00:00:17.740
# to consecrate a cemetery for Union war dead. Though brief, the now famous Gettysburg Address
#
# 00:00:17.740 --> 00:00:23.200
# marked a defining moment of the Civil War. Actor Sam Waterston has portrayed President
#
# 00:00:23.200 --> 00:00:24.980
# Lincoln on stage and screen.
#
# 00:00:24.980 --> 00:00:28.120
# Four score and seven years ago.

# %% [markdown]
# Now that we've seen how Whisper works, let's do the same thing with
# Nvidia's Parakeet in [05-Parakeet](05-Parakeet.ipynb)
